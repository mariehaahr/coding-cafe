# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
data = pd.read_csv("Noisy_Bootstrap_Vin_datasaet.csv", delimiter=";")
data
# Out:
#                     alcohol              malic_acid                     ash  \
# 0                     14.23                    1.71                    2.43
# 1                      13.2                    1.78                    2.14
# 2                     13.16                    2.36                    2.67
# 3                     14.37                    1.95                     2.5
# 4                     13.24                    2.59                    2.87
# ..                      ...                     ...                     ...
# 371  13.821.679.913.853.500   3.584.852.670.142.280  24.710.660.751.483.700
# 372  12.938.226.044.140.800  34.679.578.022.728.500   2.377.127.506.441.410
# 373  12.574.146.051.461.500  33.506.795.578.434.100   1.873.952.616.579.880
# 374  12.051.586.080.401.500     254.576.662.016.837   2.214.191.753.734.610
# 375   1.207.506.126.614.960   4.048.806.951.359.900   2.315.983.981.607.740
#
# ...

# %%
def convert(column_name):
    l = []
    l2 = []
    for i in data[column_name]:
        if len(i) > 6:
            new = float(i[0:5])
            l.append(float(new))
        else:
            l.append(float(i))
    for j in l:
        noise = random.randint(-3,3) + round(random.random(),2)
        if j > np.average(l) + 10:
            j2 = np.average(l) + noise
            l2.append(j2)
        else:
            l2.append(j)

    return l2

# %%
alc = convert("alcohol")
mal = convert("malic_acid")
data["new_alc"] = alc
data["new_mal"] = mal

plt.scatter(data["new_alc"], data["new_mal"], c=data["wine_label"])

# %%
a = "14.453.43.14"
b = float(a[0:6])
b
# Out:
# 14.453

# %%
u = round(random.random(),2)
a = random.randint(-3,3)
a
# Out:
# -2

# %%
data = pd.read_csv("new_data.csv")
data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 549    13.71        5.65  2.45               20.5       95.0           1.68
# 550    13.40        3.91  2.48               23.0      102.0           1.80
# 551    13.27        4.28  2.26               20.0      120.0           1.59
# 552    13.17        2.59  2.37               20.0      120.0           1.65
# 553    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
def add_noise(column_name):
    l = []
    for i in data[column_name]:
        noise = random.randint(-3,3) + round(random.random(),3)
        new = i + noise
        l.append(new)
    return l

# %%
data["new_alc"] = add_noise("alcohol")
data["new_mal"] = add_noise("malic_acid")

# %%
data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 549    13.71        5.65  2.45               20.5       95.0           1.68
# 550    13.40        3.91  2.48               23.0      102.0           1.80
# 551    13.27        4.28  2.26               20.0      120.0           1.59
# 552    13.17        2.59  2.37               20.0      120.0           1.65
# 553    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(15,7))
ax[0].scatter(data["new_alc"], data["new_mal"], c=data["wine_label"], s=5)
ax[1].scatter(data["alcohol"], data["malic_acid"], c=data["wine_label"], s=5)

# %%
data_clean = pd.read_csv("new_data.csv")
save = data_clean.drop(['cluster'], axis=1)
save
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 549    13.71        5.65  2.45               20.5       95.0           1.68
# 550    13.40        3.91  2.48               23.0      102.0           1.80
# 551    13.27        4.28  2.26               20.0      120.0           1.59
# 552    13.17        2.59  2.37               20.0      120.0           1.65
# 553    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
save.to_csv('wine.csv')
